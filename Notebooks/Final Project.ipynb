# %% [markdown]
# ### Imports

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# Set the default seaborn style to 'darkgrid'
sns.set_theme(style="darkgrid")

# Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Aðeins að skoða gögn og þannig
# Virðist vera að við joinum á `HEINUM` til að sameina **kaupskra** og **stadfangaskra**, og svo er `FASTNUM` unique id fyrir hverja og eina fasteign.

# %%
# Þessir path-ar virka bara fyrir Þór
fig_path = '/Users/thorg/Documents/GitHub/thg205.github.io/assets'
kaupskra_path = '/Users/thorg/Desktop/kaupskra.csv'
stadfangaskra_path = '/Users/thorg/Desktop/stadfangaskra.csv'

# %%
# Reading in kaupskra data
kaupskra = pd.read_csv(kaupskra_path, encoding='latin1', sep=';')
stadfangaskra = pd.read_csv(stadfangaskra_path, encoding='utf-8', sep=',')

# %%
#kaupskra
kaupskra.loc[(kaupskra['HEINUM'] == 1024617) & (kaupskra['FASTNUM'] == 2067729)]
#kaupskra.loc[kaupskra['HEIMILISFANG'] == 'Kolbeinsmýri 10']
# Out:
#         FAERSLUNUMER  EMNR    SKJALANUMER  FASTNUM HEIMILISFANG  POSTNR  \
# 0             500342   411  R-005069/2006  2067729  Melabraut 3     170
# 158343        680332   441  A-009807/2021  2067729  Melabraut 3     170
# 184701        705839   441  B-010279/2023  2067729  Melabraut 3     170
#
#          HEINUM  SVFN                  SVEITARFELAG                 UTGDAG  \
# 0       1024617  1100  Seltjarnarnesbær              2006-05-08 00:00:00.0
# 158343  1024617  1100  Seltjarnarnesbær              2021-11-01 00:00:00.0
# 184701  1024617  1100  Seltjarnarnesbær              2023-11-15 00:00:00.0
#
#                 THINGLYSTDAGS  KAUPVERD  FASTEIGNAMAT  FASTEIGNAMAT_GILDANDI  \
# 0       2006-05-10 09:22:39.0     25500         19610                90600.0
# 158343  2021-11-04 15:14:48.0     44000         48850                90600.0
# 184701  2023-11-25 14:57:33.0     86500         84300                90600.0
#
#         BRUNABOTAMAT_GILDANDI BYGGAR FEPILOG  EINFLM  LOD_FLM LOD_FLMEIN  \
# 0                     53950.0   1963  010101   102.3      NaN        NaN
# 158343                53950.0   1963  010101   102.3    820.0         m²
# 184701                53950.0   2023  010101   107.2    820.0         m²
#
#         FJHERB    TEGUND  FULLBUID  ONOTHAEFUR_SAMNINGUR
# 0          3.0  Fjölbýli         1                     1
# 158343     3.0  Fjölbýli         1                     0
# 184701     3.0  Fjölbýli         1                     1

# %%
#stadfangaskra
stadfangaskra.loc[stadfangaskra['HEINUM'] == 1024617]
# Out:
#                                                 FID   HNITNUM  SVFNR  BYGGD  \
# 40877  Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
#
#        LANDNR   HEINUM  MATSNR  POSTNR   HEITI_NF  HEITI_TGF  HUSNR BOKST  \
# 40877  117368  1024617     NaN     170  Melabraut  Melabraut    3.0   NaN
#
#       VIDSK SERHEITI    DAGS_INN  DAGS_LEIDR GAGNA_EIGN  TEGHNIT  YFIRFARID  \
# 40877   NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
#
#        YFIRF_HEITI  ATH  NAKV_XY                   HNIT  N_HNIT_WGS84  \
# 40877          NaN  NaN      NaN  POINT (354080 408959)     64.152289
#
#        E_HNIT_WGS84  NOTNR        LM_HEIMILISFANG            VEF_BIRTING  \
# 40877    -21.999498  956.0  Melabraut 3  (117368)  Melabraut 3  (117368)
#
#       HUSMERKING
# 40877          3

# %%
# Lets join kaupskra and stadfangaskra together to form our dataset
data = pd.merge(kaupskra, stadfangaskra, on='HEINUM') # inner join
data
# Out:
#         FAERSLUNUMER  EMNR    SKJALANUMER  FASTNUM    HEIMILISFANG  POSTNR_x  \
# 0             500342   411  R-005069/2006  2067729     Melabraut 3       170
# 1             679963   441  D-006418/2021  2067730     Melabraut 3       170
# 2             680332   441  A-009807/2021  2067729     Melabraut 3       170
# 3             702045   441  B-005352/2023  2526176     Melabraut 3       170
# 4             705839   441  B-010279/2023  2067729     Melabraut 3       170
# ...              ...   ...            ...      ...             ...       ...
# 193000        709514   441  A-003338/2024  2527571   Dofrahella 8J       221
# 193001        709537   441  B-002467/2024  2297716    Hringhella 8       221
# 193002        709627   441  A-004053/2024  2022785   Barðavogur 36       104
# 193003        709627   441  A-004053/2024  2022784   Barðavogur 36       104
# 193004        709701   441  A-004237/2024  2515382  Stuðlaskarð 8B       221
#
#          HEINUM  SVFN                  SVEITARFELAG                 UTGDAG  \
# 0       1024617  1100  Seltjarnarnesbær              2006-05-08 00:00:00.0
# 1       1024617  1100  Seltjarnarnesbær              2021-10-21 00:00:00.0
# 2       1024617  1100  Seltjarnarnesbær              2021-11-01 00:00:00.0
# 3       1024617  1100  Seltjarnarnesbær              2023-06-27 00:00:00.0
# 4       1024617  1100  Seltjarnarnesbær              2023-11-15 00:00:00.0
# ...         ...   ...                           ...                    ...
# 193000  1212568  1400  Hafnarfjarðarkaupstaður       2024-02-26 00:00:00.0
# 193001  1100502  1400  Hafnarfjarðarkaupstaður       2024-02-28 00:00:00.0
# 193002  1001936     0  Reykjavíkurborg               2024-02-19 00:00:00.0
# 193003  1001936     0  Reykjavíkurborg               2024-02-19 00:00:00.0
# 193004  1205692  1400  Hafnarfjarðarkaupstaður       2024-02-28 00:00:00.0
#
#                 THINGLYSTDAGS  KAUPVERD  FASTEIGNAMAT  FASTEIGNAMAT_GILDANDI  \
# 0       2006-05-10 09:22:39.0     25500         19610                90600.0
# 1       2021-10-25 15:18:50.0     50000         62250               100400.0
# 2       2021-11-04 15:14:48.0     44000         48850                90600.0
# 3       2023-08-03 12:17:21.0    119900         10200                99350.0
# 4       2023-11-25 14:57:33.0     86500         84300                90600.0
# ...                       ...       ...           ...                    ...
# 193000  2024-03-15 09:33:44.0     26400         20000                20000.0
# 193001  2024-03-15 10:55:21.0     48500         46000                46000.0
# 193002  2024-03-18 14:10:44.0    156900         83550                83550.0
# 193003  2024-03-18 14:10:44.0    156900         73200                73200.0
# 193004  2024-03-20 10:42:10.0     82900         75150                75150.0
#
#         BRUNABOTAMAT_GILDANDI BYGGAR FEPILOG  EINFLM  LOD_FLM LOD_FLMEIN  \
# 0                     53950.0   1963  010101   102.3      NaN        NaN
# 1                     67900.0   1963  010201   139.8    820.0         m²
# 2                     53950.0   1963  010101   102.3    820.0         m²
# 3                     67950.0         010301   129.5    820.0         m²
# 4                     53950.0   2023  010101   107.2    820.0         m²
# ...                       ...    ...     ...     ...      ...        ...
# 193000                24850.0   2023  010110    60.5   2998.0         m²
# 193001                71150.0   2009  010103   142.5   2763.8
# 193002                76900.0   1954  010201   283.8    614.0         m²
# 193003                70200.0   1954  010101   283.8    614.0         m²
# 193004                47250.0   2022  010102    91.5   1072.1         m²
#
#         FJHERB          TEGUND  FULLBUID  ONOTHAEFUR_SAMNINGUR  \
# 0          3.0        Fjölbýli         1                     1
# 1          2.0        Fjölbýli         1                     0
# 2          3.0        Fjölbýli         1                     0
# 3          2.0        Fjölbýli         1                     1
# 4          3.0        Fjölbýli         1                     1
# ...        ...             ...       ...                   ...
# 193000     NaN  Atvinnuhúsnæði         1                     0
# 193001     NaN  Atvinnuhúsnæði         1                     0
# 193002     3.0        Fjölbýli         1                     1
# 193003     3.0        Fjölbýli         1                     1
# 193004     3.0         Sérbýli         1                     0
#
#                                                  FID   HNITNUM  SVFNR  BYGGD  \
# 0       Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
# 1       Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
# 2       Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
# 3       Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
# 4       Stadfangaskra.fid-24f8547a_18ebb06342d_-3298  10032272   1100      1
# ...                                              ...       ...    ...    ...
# 193000  Stadfangaskra.fid-24f8547a_18ebb06342d_-6390  10158170   1400      1
# 193001  Stadfangaskra.fid-24f8547a_18ebb06342d_-521e  10075078   1400      1
# 193002   Stadfangaskra.fid-24f8547a_18ebac741ee_565d  10007611      0      1
# 193003   Stadfangaskra.fid-24f8547a_18ebac741ee_565d  10007611      0      1
# 193004  Stadfangaskra.fid-24f8547a_18ebb069336_-286b  10142934   1400      1
#
#         LANDNR  MATSNR  POSTNR_y     HEITI_NF     HEITI_TGF  HUSNR BOKST  \
# 0       117368     NaN       170    Melabraut     Melabraut    3.0   NaN
# 1       117368     NaN       170    Melabraut     Melabraut    3.0   NaN
# 2       117368     NaN       170    Melabraut     Melabraut    3.0   NaN
# 3       117368     NaN       170    Melabraut     Melabraut    3.0   NaN
# 4       117368     NaN       170    Melabraut     Melabraut    3.0   NaN
# ...        ...     ...       ...          ...           ...    ...   ...
# 193000  232020     NaN       221   Dofrahella    Dofrahellu    8.0     J
# 193001  189374     NaN       221   Hringhella    Hringhellu    8.0   NaN
# 193002  105491     NaN       104   Barðavogur     Barðavogi   36.0   NaN
# 193003  105491     NaN       104   Barðavogur     Barðavogi   36.0   NaN
# 193004  227946     NaN       221  Stuðlaskarð  Stuðlaskarði    8.0     B
#
#        VIDSK SERHEITI    DAGS_INN  DAGS_LEIDR GAGNA_EIGN  TEGHNIT  YFIRFARID  \
# 0        NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# 1        NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# 2        NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# 3        NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# 4        NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# ...      ...      ...         ...         ...        ...      ...        ...
# 193000   NaN      NaN  2023-07-11  2023-07-11        HMS      0.0        0.0
# 193001   NaN      NaN  2007-09-07  2009-02-23        HMS      0.0        0.0
# 193002   NaN      NaN  2007-09-07  2010-01-05        HMS      0.0        0.0
# 193003   NaN      NaN  2007-09-07  2010-01-05        HMS      0.0        0.0
# 193004   NaN      NaN  2021-07-20  2021-11-26        HMS      5.0        0.0
#
#         YFIRF_HEITI                                      ATH  NAKV_XY  \
# 0               NaN                                      NaN      NaN
# 1               NaN                                      NaN      NaN
# 2               NaN                                      NaN      NaN
# 3               NaN                                      NaN      NaN
# 4               NaN                                      NaN      NaN
# ...             ...                                      ...      ...
# 193000          NaN                        Póstnúmer uppfært      NaN
# 193001          NaN                                      NaN      NaN
# 193002          NaN                                      NaN      NaN
# 193003          NaN                                      NaN      NaN
# 193004          NaN  Lagfært heiti - uppruni úr ifx:stadfang      NaN
#
#                                              HNIT  N_HNIT_WGS84  E_HNIT_WGS84  \
# 0                           POINT (354080 408959)     64.152289    -21.999498
# 1                           POINT (354080 408959)     64.152289    -21.999498
# 2                           POINT (354080 408959)     64.152289    -21.999498
# 3                           POINT (354080 408959)     64.152289    -21.999498
# 4                           POINT (354080 408959)     64.152289    -21.999498
# ...                                           ...           ...           ...
# 193000                      POINT (354179 395792)     64.034356    -21.984697
# 193001                      POINT (353457 397215)     64.046799    -22.000834
# 193002  POINT (361207.504545455 406324.731818182)     64.131642    -21.850750
# 193003  POINT (361207.504545455 406324.731818182)     64.131642    -21.850750
# 193004                      POINT (355816 396974)     64.045636    -21.952368
#
#         NOTNR           LM_HEIMILISFANG               VEF_BIRTING HUSMERKING
# 0       956.0     Melabraut 3  (117368)     Melabraut 3  (117368)          3
# 1       956.0     Melabraut 3  (117368)     Melabraut 3  (117368)          3
# 2       956.0     Melabraut 3  (117368)     Melabraut 3  (117368)          3
# 3       956.0     Melabraut 3  (117368)     Melabraut 3  (117368)          3
# 4       956.0     Melabraut 3  (117368)     Melabraut 3  (117368)          3
# ...       ...                       ...                       ...        ...
# 193000  956.0   Dofrahella 8J  (232020)   Dofrahella 8J  (232020)         8J
# 193001  956.0    Hringhella 8  (189374)    Hringhella 8  (189374)          8
# 193002  956.0   Barðavogur 36  (105491)   Barðavogur 36  (105491)         36
# 193003  956.0   Barðavogur 36  (105491)   Barðavogur 36  (105491)         36
# 193004  956.0  Stuðlaskarð 8B  (227946)  Stuðlaskarð 8B  (227946)         8B
#
# [193005 rows x 52 columns]

# %% [markdown]
# # Motivation
# - What is your dataset?
# - Why did you choose this/these particular dataset(s)?
# - What was your goal for the end user's experience?

# %% [markdown]
# # Basic stats
# Let's understand the dataset better:
# - Write about your choices in data cleaning and preprocessing
# - Write a short section that discusses the dataset stats, containing key points/plots from your exploratory data analysis.

# %% [markdown]
# # Data Analysis
# - Describe your data analysis and explain what you've learned about the dataset.
# - If relevant, talk about your machine-learning.

# %% [markdown]
# # Genre
# Which genre of data story did you use?
# - Which tools did you use from each of the 3 categories of Visual Narrative (Figure 7 in Segal and Heer). Why?
# - Which tools did you use from each of the 3 categories of Narrative Structure (Figure 7 in Segal and Heer). Why?

# %% [markdown]
# # Visualizations
# - Explain the visualizations you've chosen.
# - Why are they right for the story you want to tell?

# %% [markdown]
# # Discussion
# Think critically about your creation
# What went well?,
# What is still missing? What could be improved?, Why?

# %% [markdown]
# # Contributions
# Who did what?
# - You should write (just briefly) which group member was the main responsible for which elements of the assignment. (I want you guys to understand every part of the assignment, but usually there is someone who took lead role on certain portions of the work. That's what you should explain).
# - It is not OK simply to write "All group members contributed equally".
